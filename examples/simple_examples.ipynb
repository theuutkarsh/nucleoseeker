# %% [markdown]
# **NOTE** Please follow the instructions in README file before executing the cells in this Jupyter Notebook.

# %%
import pandas as pd
import numpy as np
import os
from Bio.PDB.MMCIFParser import MMCIFParser, MMCIF2Dict

# %%
RFAM_PATH =  # path to the Rfam covariance model
DATA_PATH = "../test/"
os.environ["DATA_PATH"] = DATA_PATH

# %%
import nucleoseeker.dataset_creator as dataset_creator
import nucleoseeker.dataset_download as dataset_download
import nucleoseeker.individual_structure_filter as individual_structure_filter
import nucleoseeker.columns as columns
import nucleoseeker.structure_comparison_filter as structure_comparison_filter
import nucleoseeker.metadata_filter as metadata_filter
import nucleoseeker.utils as utils

# %% [markdown]
# ## Understanding the standalone use of each module

# %% [markdown]
# ### How to use the `DatasetDownload` module?

# %% [markdown]
# This module is used to download data from the RCSB PDB database. It uses API calls to fetch the data. This provides a dataframe containing all the structures with their characteristics for the given criteria.
#
# `dstart` and `dend` are used to specify the search results that are captured by the tool. If you want to analyse all available RNA data then `dstart=0` and `dend=10000` or `download_all=True` should be used. At later time, when number of RNA structures exceeds 10000, we would update this limit further.
#
# The dataframe fetched can be accessed with the `df` attribute of the class.
#
# Here is a simple usage example:

# %%
download = dataset_download.DatasetDownload(
    structure_determination_methodology = 'experimental',
    rcsb_entity_polymer_type = 'RNA',
    dstart = 0,
    dend = 100,
)

# %% [markdown]
# **Accessing the dataframe with `df` attribute**

# %%
rawdf = download.df

# %%
rawdf
# Out:
#    rcsb_id         exptl_method release_date  polymer_entity_instance_count  \
# 0     124d         SOLUTION NMR         1993                              2
# 1     157d    X-RAY DIFFRACTION         1994                              2
# 2     165d    X-RAY DIFFRACTION         1994                              2
# 3     176d         SOLUTION NMR         1994                              2
# 4     17ra         SOLUTION NMR         1999                              1
# ..     ...                  ...          ...                            ...
# 95    1efo    X-RAY DIFFRACTION         2000                              2
# 96    1efs         SOLUTION NMR         2000                              2
# 97    1efw    X-RAY DIFFRACTION         2000                              4
# 98    1eg0  ELECTRON MICROSCOPY         2000                             15
# 99    1egk    X-RAY DIFFRACTION         2000                              4
#
#     polymer_entity_count_RNA  resolution selected_polymer_entity_types  \
# 0                          1         NaN           Nucleic acid (only)
# 1                          1        1.80           Nucleic acid (only)
# 2                          1        1.55           Nucleic acid (only)
# 3                          1         NaN                         Other
# 4                          1         NaN           Nucleic acid (only)
# ..                       ...         ...                           ...
# 95                         1        2.30           Nucleic acid (only)
# 96                         1         NaN           Nucleic acid (only)
# 97                         1        3.00                    Protein/NA
# 98                         4       11.50                    Protein/NA
# 99                         1        3.10           Nucleic acid (only)
#
#                pdbx_keywords
# 0             DNA-RNA HYBRID
# 1                        RNA
# 2             DNA-RNA HYBRID
# 3   PEPTIDE NUCLEIC ACID/RNA
# 4                        RNA
# ..                       ...
# 95            DNA-RNA HYBRID
# 96            DNA-RNA HYBRID
# 97                LIGASE/RNA
# 98                  RIBOSOME
# 99            DNA-RNA HYBRID
#
# [100 rows x 8 columns]

# %% [markdown]
# ### How to use the `MetadataFilter` module?

# %% [markdown]
# This module allows the application of structure level filters like experimental method, resolution and release year on a dataframe. It requires a dataframe to work, you can use the dataframe we obtained in the *previous step* or provide your own dataframe.
#
# Make sure that the dataframe you provide has the same columns as given in `COLUMNS` module.
#
# The filters of this module can be applied *individually* if you don't want to apply all of them together.
#
# Here is a simple example:

# %%
struct_filter = metadata_filter.MetadataFilter(
    exptl_method = ['X-RAY DIFFRACTION'],
    resolution = 3.6,
    year_range = [1995, 2000],
    polymer_entity_instance_count=None,
    polymer_entity_count_RNA=None,
    selected_polymer_entity_types=None,
    pdbx_keywords=None
)

# %% [markdown]
# **Applying a single filter**

# %%
single_filter_df = struct_filter.apply_resolution_filter(rawdf)

# %%
single_filter_df
# Out:
#    rcsb_id       exptl_method release_date  polymer_entity_instance_count  \
# 0     157d  X-RAY DIFFRACTION         1994                              2
# 1     165d  X-RAY DIFFRACTION         1994                              2
# 2     1a34  X-RAY DIFFRACTION         1998                              3
# 3     1a9n  X-RAY DIFFRACTION         1998                              6
# 4     1aq3  X-RAY DIFFRACTION         1997                              5
# 5     1aq4  X-RAY DIFFRACTION         1997                              5
# 6     1asy  X-RAY DIFFRACTION         1995                              4
# 7     1asz  X-RAY DIFFRACTION         1995                              4
# 8     1av6  X-RAY DIFFRACTION         1998                              2
# 9     1b23  X-RAY DIFFRACTION         1998                              2
# 10    1b2m  X-RAY DIFFRACTION         1999                              5
# 11    1b7f  X-RAY DIFFRACTION         1999                              4
# 12    1bmv  X-RAY DIFFRACTION         1989                              3
# 13    1br3  X-RAY DIFFRACTION         1999                              2
# 14    1c0a  X-RAY DIFFRACTION         1999                              2
# 15    1c9s  X-RAY DIFFRACTION         1999                             23
# 16    1cgm  FIBER DIFFRACTION         1994                              2
# 17    1csl  X-RAY DIFFRACTION         2000                              2
# 18    1cvj  X-RAY DIFFRACTION         1999                             16
# 19    1cwp  X-RAY DIFFRACTION         1995                              6
# 20    1d4r  X-RAY DIFFRACTION         1999                              3
# 21    1ddl  X-RAY DIFFRACTION         2000                              5
# 22    1ddy  X-RAY DIFFRACTION         2000                              4
# 23    1dfu  X-RAY DIFFRACTION         1999                              3
# 24    1di2  X-RAY DIFFRACTION         1999                              6
# 25    1dk1  X-RAY DIFFRACTION         2000                              2
# 26    1dqf  X-RAY DIFFRACTION         2000                              2
# 27    1dqh  X-RAY DIFFRACTION         2000                              2
# 28    1drz  X-RAY DIFFRACTION         1999                              2
# 29    1duh  X-RAY DIFFRACTION         2000                              1
# 30    1dul  X-RAY DIFFRACTION         2000                              2
# 31    1duq  X-RAY DIFFRACTION         2000                              8
# 32    1e7k  X-RAY DIFFRACTION         2001                              4
# 33    1e8o  X-RAY DIFFRACTION         2000                              5
# 34    1ec6  X-RAY DIFFRACTION         2000                              4
# 35    1efo  X-RAY DIFFRACTION         2000                              2
# 36    1efw  X-RAY DIFFRACTION         2000                              4
# 37    1egk  X-RAY DIFFRACTION         2000                              4
#
#     polymer_entity_count_RNA  resolution selected_polymer_entity_types  \
# 0                          1        1.80           Nucleic acid (only)
# 1                          1        1.55           Nucleic acid (only)
# 2                          2        1.81                    Protein/NA
# 3                          1        2.38                    Protein/NA
# 4                          1        2.80                    Protein/NA
# 5                          1        3.00                    Protein/NA
# 6                          1        2.90                    Protein/NA
# 7                          1        3.00                    Protein/NA
# 8                          1        2.80                    Protein/NA
# 9                          1        2.60                    Protein/NA
# 10                         1        2.00                    Protein/NA
# 11                         1        2.60                    Protein/NA
# 12                         1        3.00                    Protein/NA
# 13                         1        3.00           Nucleic acid (only)
# 14                         1        2.40                    Protein/NA
# 15                         1        1.90                    Protein/NA
# 16                         1        3.40                    Protein/NA
# 17                         2        1.60           Nucleic acid (only)
# 18                         1        2.60                    Protein/NA
# 19                         2        3.20                    Protein/NA
# 20                         2        2.00           Nucleic acid (only)
# 21                         2        2.70                    Protein/NA
# 22                         1        3.00           Nucleic acid (only)
# 23                         2        1.80                    Protein/NA
# 24                         1        1.90                    Protein/NA
# 25                         1        2.80                    Protein/NA
# 26                         2        2.20           Nucleic acid (only)
# 27                         2        1.70           Nucleic acid (only)
# 28                         1        2.30                    Protein/NA
# 29                         1        2.70           Nucleic acid (only)
# 30                         1        1.80                    Protein/NA
# 31                         2        2.10           Nucleic acid (only)
# 32                         1        2.90                    Protein/NA
# 33                         1        3.20                    Protein/NA
# 34                         1        2.40                    Protein/NA
# 35                         1        2.30           Nucleic acid (only)
# 36                         1        3.00                    Protein/NA
# 37                         1        3.10           Nucleic acid (only)
#
#                              pdbx_keywords
# 0                                      RNA
# 1                           DNA-RNA HYBRID
# 2                                Virus/RNA
# 3                  RNA BINDING PROTEIN/RNA
# 4                                Virus/RNA
# 5                                Virus/RNA
# 6   COMPLEX (AMINOACYL-TRNA SYNTHASE/TRNA)
# 7   COMPLEX (AMINOACYL-TRNA SYNTHASE/TRNA)
# 8                          TRANSFERASE/RNA
# 9                      GENE REGULATION/RNA
# 10                           HYDROLASE/RNA
# 11                 RNA-BINDING PROTEIN/RNA
# 12                               Virus/RNA
# 13                          DNA-RNA HYBRID
# 14                              LIGASE/RNA
# 15                 RNA BINDING PROTEIN/RNA
# 16                                   VIRUS
# 17                                     RNA
# 18                     GENE REGULATION/RNA
# 19                               Virus/RNA
# 20                                     RNA
# 21                               Virus/RNA
# 22                                     RNA
# 23                                RIBOSOME
# 24                 RNA BINDING PROTEIN/RNA
# 25                                RIBOSOME
# 26                                     RNA
# 27                                     RNA
# 28                 RNA BINDING PROTEIN/RNA
# 29                                     RNA
# 30                   SIGNALING PROTEIN/RNA
# 31                                     RNA
# 32                     RNA BINDING PROTEIN
# 33          ALU RIBONUCLEOPROTEIN PARTICLE
# 34                 RNA BINDING PROTEIN/RNA
# 35                          DNA-RNA HYBRID
# 36                              LIGASE/RNA
# 37                          DNA-RNA HYBRID

# %% [markdown]
# **Apply all filters together**

# %%
struct_filter_df = struct_filter.apply_filters(rawdf)

# %%
struct_filter_df
# Out:
#    rcsb_id       exptl_method  release_date  polymer_entity_instance_count  \
# 0     1asy  X-RAY DIFFRACTION          1995                              4
# 1     1asz  X-RAY DIFFRACTION          1995                              4
# 2     1csl  X-RAY DIFFRACTION          2000                              2
# 3     1cwp  X-RAY DIFFRACTION          1995                              6
# 4     1ddl  X-RAY DIFFRACTION          2000                              5
# 5     1ddy  X-RAY DIFFRACTION          2000                              4
# 6     1dk1  X-RAY DIFFRACTION          2000                              2
# 7     1dqf  X-RAY DIFFRACTION          2000                              2
# 8     1dqh  X-RAY DIFFRACTION          2000                              2
# 9     1duh  X-RAY DIFFRACTION          2000                              1
# 10    1dul  X-RAY DIFFRACTION          2000                              2
# 11    1duq  X-RAY DIFFRACTION          2000                              8
# 12    1e8o  X-RAY DIFFRACTION          2000                              5
# 13    1ec6  X-RAY DIFFRACTION          2000                              4
# 14    1efo  X-RAY DIFFRACTION          2000                              2
# 15    1efw  X-RAY DIFFRACTION          2000                              4
# 16    1egk  X-RAY DIFFRACTION          2000                              4
#
#     polymer_entity_count_RNA  resolution selected_polymer_entity_types  \
# 0                          1         2.9                    Protein/NA
# 1                          1         3.0                    Protein/NA
# 2                          2         1.6           Nucleic acid (only)
# 3                          2         3.2                    Protein/NA
# 4                          2         2.7                    Protein/NA
# 5                          1         3.0           Nucleic acid (only)
# 6                          1         2.8                    Protein/NA
# 7                          2         2.2           Nucleic acid (only)
# 8                          2         1.7           Nucleic acid (only)
# 9                          1         2.7           Nucleic acid (only)
# 10                         1         1.8                    Protein/NA
# 11                         2         2.1           Nucleic acid (only)
# 12                         1         3.2                    Protein/NA
# 13                         1         2.4                    Protein/NA
# 14                         1         2.3           Nucleic acid (only)
# 15                         1         3.0                    Protein/NA
# 16                         1         3.1           Nucleic acid (only)
#
#                              pdbx_keywords
# 0   COMPLEX (AMINOACYL-TRNA SYNTHASE/TRNA)
# 1   COMPLEX (AMINOACYL-TRNA SYNTHASE/TRNA)
# 2                                      RNA
# 3                                Virus/RNA
# 4                                Virus/RNA
# 5                                      RNA
# 6                                 RIBOSOME
# 7                                      RNA
# 8                                      RNA
# 9                                      RNA
# 10                   SIGNALING PROTEIN/RNA
# 11                                     RNA
# 12          ALU RIBONUCLEOPROTEIN PARTICLE
# 13                 RNA BINDING PROTEIN/RNA
# 14                          DNA-RNA HYBRID
# 15                              LIGASE/RNA
# 16                          DNA-RNA HYBRID

# %% [markdown]
# ### How to use the `IndividualStructureFilter` module?

# %% [markdown]
# Like all other modules of this tool, this also works as standalone and at the same time allows analysing PDB files which are not related to this tool.
#
# Suppose you have a PDB file and you want to see if it satisfies some criteria then this module can be very handy. You only need to specify the PDB ID, and your criteria, this will download the PDB for you (if `auto_download=True`). It returns a list of tuples containing PDB ID, Chain ID, Sequence which satisfy your criteria.
#
# Here you can see its usage:

# %% [markdown]
# **You will get a tuple if criteria is satisfied**

# %%
pdb_fil = individual_structure_filter.IndividualStructureFilter(
    pdb_id = '1efw',
    polymer_type = 'polyribonucleotide',
    sequence_length = 10,
    auto_download = True, # turn this to True if mmcif file is not available
    pdb_parser=MMCIF2Dict
)

# %%
data_list = pdb_fil.check_polymer_type()

# %%
data_list
# Out:
# [('1efw',
#   'C',
#   'GGAGCGGUAGUUCAGUCGGUUAGAAUACCUGCCUGUCACGCAGGGGGUCGCGGGUUCGAGUCCCGUCCGUUCC')]

# %% [markdown]
# **Empty list will be returned when criteria is not satisfied**

# %%
pdb_fil = individual_structure_filter.IndividualStructureFilter(
    pdb_id = '101m',
    polymer_type = 'polyribonucleotide',
    sequence_length = 10,
    auto_download = True, # turn this to True if mmcif file is not available
    pdb_parser=MMCIF2Dict
)

# %%
data_list = pdb_fil.check_polymer_type()

# %%
data_list
# Out:
# []

# %% [markdown]
# ### How to use the `StructureComparisonFilter` module?

# %% [markdown]
# In this module, we combine the `IndividualStructureFilter` module with an alignment software such as `ClustalOmega` or `Emboss` such that it can process multiple PDB files and also filter them on the basis of sequence identity.
#
# For this section you need to have `ClustalOmega` installed otherwise it will fail. (See README)
#
# You specify the criteria and the threshold of sequence identity. It calculates pairwise sequence identity between each structure and for structures with an identity percentage above the threshold (say `sequence_identity=50.00`) it chooses the one with higher resolution.
#
# We recommend (unless you want to experiment) using `ClustalOmega` for your analysis as it is much efficient than `'Emboss`.

# %% [markdown]
# **This can be applied on a single PDB file**

# %%
poly_fil = structure_comparison_filter.StructureComparisonFilter(
    polymer_type = 'polyribonucleotide',
    sequence_length = 10,
    sequence_identity = 50.00,
    auto_download = True,
    alignment_tool = 'clustal'
)

# %%
single_pdb_data_list = poly_fil.apply_filters_on_pdb_id('1cgm')

# %%
single_pdb_data_list
# Out:
# []

# %% [markdown]
# **It also works on a list of PDB files**

# %%
multiple_pdbs_data_list = poly_fil.apply_filters_on_list(['1ehz', '1aud'])

# %%
multiple_pdbs_data_list
# Out:
# [('1ehz',
#   'A',
#   'GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGGUCCUGUGUUCGAUCCACAGAAUUCGCACCA'),
#  ('1aud', 'B', 'GGCAGAGUCCUUCGGGACAUUGCACCUGCC')]

# %% [markdown]
# **Finally, if you provide this a dataframe with other filters applied and a data_list (obtained at *previous step*), this will apply the sequence identity criteria on the dataframe and return the final dataframe**

# %%
data_list = poly_fil.apply_filters_on_list(struct_filter_df['rcsb_id'].to_list())
final_df = poly_fil.apply_filter_on_df(struct_filter_df, data_list)

# %% [markdown]
# **Here is the final dataframe with all the filters applied**

# %%
final_df
# Out:
#    rcsb_id       exptl_method  release_date  polymer_entity_instance_count  \
# 2     1csl  X-RAY DIFFRACTION          2000                              2
# 6     1dqh  X-RAY DIFFRACTION          2000                              2
# 8     1dul  X-RAY DIFFRACTION          2000                              2
# 12    1efo  X-RAY DIFFRACTION          2000                              2
#
#     polymer_entity_count_RNA  resolution selected_polymer_entity_types  \
# 2                          2         1.6           Nucleic acid (only)
# 6                          2         1.7           Nucleic acid (only)
# 8                          1         1.8                    Protein/NA
# 12                         1         2.3           Nucleic acid (only)
#
#             pdbx_keywords chain_id  \
# 2                     RNA        A
# 6                     RNA        B
# 8   SIGNALING PROTEIN/RNA        B
# 12         DNA-RNA HYBRID        B
#
#                                              sequence
# 2                                       AACGGGCGCAGAA
# 6                                          CAGGGUCGGC
# 8   GGCUCUGUUUACCAGGUCAGGUCCGAAAGGAAGCAGCCAAGGCAGAGCC
# 12                                         GAAGAGAGAG

# %% [markdown]
# **NOTE**: In the module `DatasetCreator`, we combine all the filters and search for the families of these structures using `cmscan` from `Infernal`.
